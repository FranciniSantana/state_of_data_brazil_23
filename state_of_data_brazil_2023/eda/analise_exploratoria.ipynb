# %%
# importando bibliotecas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
# Importando e lendo os dados em um dataframe pandas

file_path = r'C:\Users\frans\Documents\projeto state of data brazil\state_of_data_brazil_2023\data\state_of_data_survey.csv'
df = pd.read_csv(file_path)
df.head()
# Out:
#                        ('P0', 'id')  ('P1_a ', 'Idade')  \
# 0  001b2d1qtli8t9z7oqgdhj001b2d4i0g                  31
# 1  0026aa3fwd78u0026asg7456tfkjg2cs                  30
# 2  00r21rb9pusd1b0v7ew00r21rw3dy69w                  37
# 3  00urm3jf2cek12w6ygue00urm3jzd17j                  22
# 4  00v0az4g792svil00vn6y1kfm9hq8vy9                  34
#
#   ('P1_a_1 ', 'Faixa idade') ('P1_b ', 'Genero') ('P1_c ', 'Cor/raca/etnia')  \
# 0                      30-34           Masculino                      Branca
# 1                      30-34           Masculino                      Branca
# 2                      35-39            Feminino                     Amarela
# 3                      22-24           Masculino                       Preta
# 4                      30-34           Masculino                      Branca
#
#   ('P1_d ', 'PCD')  ('P1_e ', 'experiencia_profissional_prejudicada')  \
# 0              Não                                                NaN
# ...

# %%
# Quantas linhas e quantas colunas a tabela possui

qt_colunas, qt_linhas = df.shape
print(f"Este dataset possui {qt_colunas} colunas e {qt_linhas} linhas")
# Out:
# Este dataset possui 5293 colunas e 399 linhas
